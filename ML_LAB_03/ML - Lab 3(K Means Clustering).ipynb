# %% [markdown]
# **MACHINE LEARNING LAB - 11/06/2020 | SANDHYA M (1947139) -  3MCS**
#
# **Lab Session 3 - K-Means Algorithm**
#
# 1.	Demonstrate K Means Algorithm.
# 2.  Use at least one plot to visualize the results.

# %% [markdown]
# **Importing Packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **Loading Mall_Customers data set**

# %%
df = pd.read_csv("D:/MSC/3 sem/ML Lab/Lab 3/Mall_Customers.csv") 
x = df.iloc[:,[3,4]].values

# %% [markdown]
# **Displaying Top 5 rows of Data Set**

# %%
df.shape
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)
# 0           1    Male   19                 15                      39
# 1           2    Male   21                 15                      81
# 2           3  Female   20                 16                       6
# 3           4  Female   23                 16                      77
# 4           5  Female   31                 17                      40

# %% [markdown]
# **Datatype Info of Mall_Customers data set**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
# CustomerID                200 non-null int64
# Gender                    200 non-null object
# Age                       200 non-null int64
# Annual Income ($)         200 non-null int64
# Spending Score (1-100)    200 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# **Using Elbow method to find the optimal number of clusters**

# %%
from sklearn.cluster import KMeans

wcss = []
for i in range(1, 11):
    km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    km.fit(x)
    wcss.append(km.inertia_)

# %% [markdown]
# **Plot the graph to visualize the Elbow Method to find the optimal number of clusters**

# %%
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method', fontsize = 20)
plt.xlabel('No. of Clusters')
plt.ylabel('wcss')
plt.show()

# %% [markdown]
# **Applying K-Means to the dataset with the optimal number of cluster**

# %%
km = KMeans(n_clusters = 5, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_means = km.fit_predict(x)

# %% [markdown]
# **Visualizaing the Clusters using Scatter Plot**

# %%
plt.scatter(x[y_means == 0, 0], x[y_means == 0, 1], s = 100, c = 'pink', label = 'Cluster 1')
plt.scatter(x[y_means == 1, 0], x[y_means == 1, 1], s = 100, c = 'yellow', label = 'Cluster 2')
plt.scatter(x[y_means == 2, 0], x[y_means == 2, 1], s = 100, c = 'cyan', label = 'Cluster 3')
plt.scatter(x[y_means == 3, 0], x[y_means == 3, 1], s = 100, c = 'magenta', label = 'Cluster 4')
plt.scatter(x[y_means == 4, 0], x[y_means == 4, 1], s = 100, c = 'orange', label = 'Cluster 5')
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 200, c = 'black' , label = 'Centroids')

plt.title('Clusters of Customers', fontsize = 20)
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.legend()
plt.show()

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
ymeans = kmeans.fit_predict(x)

plt.scatter(x[ymeans == 0, 0], x[ymeans == 0, 1], s = 100, c = 'pink', label = 'Usual Customers' )
plt.scatter(x[ymeans == 1, 0], x[ymeans == 1, 1], s = 100, c = 'orange', label = 'Priority Customers')
plt.scatter(x[ymeans == 2, 0], x[ymeans == 2, 1], s = 100, c = 'lightgreen', label = 'Target Customers(Young)')
plt.scatter(x[ymeans == 3, 0], x[ymeans == 3, 1], s = 100, c = 'red', label = 'Target Customers(Old)')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 200, c = 'black')

plt.title('Cluster of Ages', fontsize = 30)
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %% [markdown]
# **Thank You**
